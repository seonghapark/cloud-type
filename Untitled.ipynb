# %%
from into_mod_update_record import *
import copy

# %%
mask = get_masks(128, 3).reshape(128, 128, 3)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.imshow(masks)

# %%
image = Image.open("images/test.jpg")
image_np = np.asarray(image)
my_image = copy.deepcopy(image_np).astype(np.float64)
swaths = [("test.jpg", my_image)]

# %%
patches = gen_patches(swaths, mask, 64, 128)

# %%
for fname, coord, patch in patches:
    plt.imshow(patch)
    break
# Out:
# test.jpg

# %%
write_patches(patches, "./out", 500)
# Out:
# test.jpg
# Writing to sample_0-3.tfrecord
# Rank 0 wrote 1 patches
# Rank 0 wrote 2 patches
# Rank 0 wrote 3 patches
# Rank 0 wrote 4 patches
# Rank 0 wrote 5 patches
# Rank 0 wrote 6 patches
# Rank 0 wrote 7 patches
# Rank 0 wrote 8 patches
# Rank 0 wrote 9 patches
# Rank 0 wrote 10 patches
# Rank 0 wrote 11 patches
# Rank 0 wrote 12 patches
# Rank 0 wrote 13 patches
# Rank 0 wrote 14 patches
# Rank 0 wrote 15 patches
# Rank 0 wrote 16 patches
# Rank 0 wrote 17 patches
# Rank 0 wrote 18 patches
# Rank 0 wrote 19 patches
# Rank 0 wrote 20 patches
# Rank 0 wrote 21 patches
# Rank 0 wrote 22 patches
# Rank 0 wrote 23 patches
# Rank 0 wrote 24 patches
# Rank 0 wrote 25 patches
# Rank 0 wrote 26 patches
# Rank 0 wrote 27 patches
# Rank 0 wrote 28 patches
# Rank 0 wrote 29 patches
# Rank 0 wrote 30 patches
# Rank 0 wrote 31 patches
# Rank 0 wrote 32 patches
# Rank 0 wrote 33 patches
# Rank 0 wrote 34 patches
# Rank 0 wrote 35 patches
# Rank 0 wrote 36 patches
# Rank 0 wrote 37 patches
# Rank 0 wrote 38 patches
# Rank 0 wrote 39 patches
# Rank 0 wrote 40 patches
# Rank 0 wrote 41 patches
# Rank 0 wrote 42 patches
# Rank 0 wrote 43 patches
# Rank 0 wrote 44 patches
# Rank 0 wrote 45 patches
# Rank 0 wrote 46 patches
# Rank 0 wrote 47 patches
# Rank 0 wrote 48 patches
# Rank 0 wrote 49 patches
# Rank 0 wrote 50 patches
# Rank 0 wrote 51 patches
# Rank 0 wrote 52 patches
# Rank 0 wrote 53 patches
# Rank 0 wrote 54 patches
# Rank 0 wrote 55 patches
# Rank 0 wrote 56 patches
# Rank 0 wrote 57 patches
# Rank 0 wrote 58 patches
# Rank 0 wrote 59 patches
# Rank 0 wrote 60 patches
# Rank 0 wrote 61 patches
# Rank 0 wrote 62 patches
# Rank 0 wrote 63 patches
# Rank 0 wrote 64 patches
# Rank 0 wrote 65 patches
# Rank 0 wrote 66 patches
# Rank 0 wrote 67 patches
# Rank 0 wrote 68 patches
# Rank 0 wrote 69 patches
# Rank 0 wrote 70 patches
# Rank 0 wrote 71 patches
# Rank 0 wrote 72 patches
# Rank 0 wrote 73 patches
# Rank 0 wrote 74 patches
# Rank 0 wrote 75 patches
# Rank 0 wrote 76 patches
# Rank 0 wrote 77 patches
# Rank 0 wrote 78 patches
# Rank 0 wrote 79 patches
# Rank 0 wrote 80 patches
# Rank 0 wrote 81 patches
# Rank 0 wrote 82 patches
# Rank 0 wrote 83 patches
# Rank 0 wrote 84 patches
# Rank 0 wrote 85 patches
# Rank 0 wrote 86 patches
# Rank 0 wrote 87 patches
# Rank 0 wrote 88 patches
# Rank 0 wrote 89 patches
# Rank 0 wrote 90 patches
# Rank 0 wrote 91 patches
# Rank 0 wrote 92 patches
# Rank 0 wrote 93 patches
# Rank 0 wrote 94 patches
# Rank 0 wrote 95 patches
# Rank 0 wrote 96 patches
# Rank 0 wrote 97 patches
# Rank 0 wrote 98 patches
# Rank 0 wrote 99 patches
# Rank 0 wrote 100 patches
# Rank 0 wrote 101 patches
# Rank 0 wrote 102 patches
# Rank 0 wrote 103 patches
# Rank 0 wrote 104 patches
# Rank 0 wrote 105 patches
# Rank 0 wrote 106 patches
# Rank 0 wrote 107 patches
# Rank 0 wrote 108 patches
# Rank 0 wrote 109 patches
# Rank 0 wrote 110 patches
# Rank 0 wrote 111 patches
# Rank 0 wrote 112 patches
# Rank 0 wrote 113 patches
# Rank 0 wrote 114 patches
# Rank 0 wrote 115 patches
# Rank 0 wrote 116 patches
# Rank 0 wrote 117 patches
# Rank 0 wrote 118 patches
# Rank 0 wrote 119 patches
# Rank 0 wrote 120 patches
# Rank 0 wrote 121 patches
# Rank 0 wrote 122 patches
# Rank 0 wrote 123 patches
# Rank 0 wrote 124 patches
# Rank 0 wrote 125 patches
# Rank 0 wrote 126 patches
# Rank 0 wrote 127 patches
# Rank 0 wrote 128 patches
# Rank 0 wrote 129 patches
# Rank 0 wrote 130 patches
# Rank 0 wrote 131 patches
# Rank 0 wrote 132 patches
# Rank 0 wrote 133 patches
# Rank 0 wrote 134 patches
# Rank 0 wrote 135 patches
# Rank 0 wrote 136 patches
# Rank 0 wrote 137 patches
# Rank 0 wrote 138 patches
# Rank 0 wrote 139 patches
# Rank 0 wrote 140 patches
# Rank 0 wrote 141 patches
# Rank 0 wrote 142 patches
# Rank 0 wrote 143 patches
# Rank 0 wrote 144 patches
# Rank 0 wrote 145 patches
# Rank 0 wrote 146 patches
# Rank 0 wrote 147 patches
# Rank 0 wrote 148 patches
# Rank 0 wrote 149 patches
# Rank 0 wrote 150 patches
# Rank 0 wrote 151 patches
# Rank 0 wrote 152 patches
# Rank 0 wrote 153 patches
# Rank 0 wrote 154 patches
# Rank 0 wrote 155 patches
# Rank 0 wrote 156 patches
# Rank 0 wrote 157 patches
# Rank 0 wrote 158 patches
# Rank 0 wrote 159 patches
# Rank 0 wrote 160 patches
# Rank 0 wrote 161 patches
# Rank 0 wrote 162 patches
# Rank 0 wrote 163 patches
# Rank 0 wrote 164 patches
# Rank 0 wrote 165 patches
# Rank 0 wrote 166 patches
# Rank 0 wrote 167 patches
# Rank 0 wrote 168 patches
# Rank 0 wrote 169 patches
# Rank 0 wrote 170 patches
# Rank 0 wrote 171 patches
# Rank 0 wrote 172 patches
# Rank 0 wrote 173 patches
# Rank 0 wrote 174 patches
# Rank 0 wrote 175 patches
# Rank 0 wrote 176 patches
# Rank 0 wrote 177 patches
# Rank 0 wrote 178 patches
# Rank 0 wrote 179 patches
# Rank 0 wrote 180 patches
# Rank 0 wrote 181 patches
# Rank 0 wrote 182 patches
# Rank 0 wrote 183 patches
# Rank 0 wrote 184 patches
# Rank 0 wrote 185 patches
# Rank 0 wrote 186 patches
# Rank 0 wrote 187 patches
# Rank 0 wrote 188 patches
# Rank 0 wrote 189 patches
# Rank 0 wrote 190 patches
# Rank 0 wrote 191 patches
# Rank 0 wrote 192 patches
# Rank 0 wrote 193 patches
# Rank 0 wrote 194 patches
# Rank 0 wrote 195 patches
# Rank 0 wrote 196 patches
# Rank 0 wrote 197 patches
# Rank 0 wrote 198 patches
# Rank 0 wrote 199 patches
# Rank 0 wrote 200 patches
# Rank 0 wrote 201 patches
# Rank 0 wrote 202 patches
# Rank 0 wrote 203 patches
# Rank 0 wrote 204 patches
# Rank 0 wrote 205 patches
# Rank 0 wrote 206 patches
# Rank 0 wrote 207 patches
# Rank 0 wrote 208 patches
# Rank 0 wrote 209 patches
# Rank 0 wrote 210 patches
# Rank 0 wrote 211 patches
# Rank 0 wrote 212 patches
# Rank 0 wrote 213 patches
# Rank 0 wrote 214 patches
# Rank 0 wrote 215 patches
# Rank 0 wrote 216 patches
# Rank 0 wrote 217 patches
# Rank 0 wrote 218 patches
# Rank 0 wrote 219 patches
# Rank 0 wrote 220 patches
# Rank 0 wrote 221 patches
# Rank 0 wrote 222 patches
# Rank 0 wrote 223 patches
# Rank 0 wrote 224 patches
# Rank 0 wrote 225 patches
# Rank 0 wrote 226 patches
# Rank 0 wrote 227 patches
# Rank 0 wrote 228 patches
# Rank 0 wrote 229 patches
# Rank 0 wrote 230 patches
# Rank 0 wrote 231 patches
# Rank 0 wrote 232 patches
# Rank 0 wrote 233 patches
# Rank 0 wrote 234 patches
# Rank 0 wrote 235 patches
# Rank 0 wrote 236 patches
# Rank 0 wrote 237 patches
# Rank 0 wrote 238 patches
# Rank 0 wrote 239 patches
# Rank 0 wrote 240 patches
# Rank 0 wrote 241 patches
# Rank 0 wrote 242 patches
# Rank 0 wrote 243 patches
# Rank 0 wrote 244 patches
# Rank 0 wrote 245 patches
# Rank 0 wrote 246 patches
# Rank 0 wrote 247 patches
# Rank 0 wrote 248 patches
# Rank 0 wrote 249 patches
# Rank 0 wrote 250 patches
# Rank 0 wrote 251 patches
# Rank 0 wrote 252 patches
# Rank 0 wrote 253 patches
# Rank 0 wrote 254 patches
# Rank 0 wrote 255 patches
# Rank 0 wrote 256 patches
# Rank 0 wrote 257 patches
# Rank 0 wrote 258 patches
# Rank 0 wrote 259 patches
# Rank 0 wrote 260 patches
# Rank 0 wrote 261 patches
# Rank 0 wrote 262 patches
# Rank 0 wrote 263 patches
# Rank 0 wrote 264 patches
# Rank 0 wrote 265 patches
# Rank 0 wrote 266 patches
# Rank 0 wrote 267 patches
# Rank 0 wrote 268 patches
# Rank 0 wrote 269 patches
# Rank 0 wrote 270 patches
# Rank 0 wrote 271 patches
# Rank 0 wrote 272 patches
# Rank 0 wrote 273 patches
# Rank 0 wrote 274 patches
# Rank 0 wrote 275 patches
# Rank 0 wrote 276 patches
# Rank 0 wrote 277 patches
# Rank 0 wrote 278 patches
# Rank 0 wrote 279 patches
# Rank 0 wrote 280 patches
# Rank 0 wrote 281 patches
# Rank 0 wrote 282 patches
# Rank 0 wrote 283 patches
# Rank 0 wrote 284 patches
# Rank 0 wrote 285 patches
# Rank 0 wrote 286 patches
# Rank 0 wrote 287 patches
# Rank 0 wrote 288 patches
# Rank 0 wrote 289 patches
# Rank 0 wrote 290 patches
# Rank 0 wrote 291 patches
# Rank 0 wrote 292 patches
# Rank 0 wrote 293 patches
# Rank 0 wrote 294 patches
# Rank 0 wrote 295 patches
# Rank 0 wrote 296 patches
# Rank 0 wrote 297 patches
# Rank 0 wrote 298 patches
# Rank 0 wrote 299 patches
# Rank 0 wrote 300 patches
# Rank 0 wrote 301 patches
# Rank 0 wrote 302 patches
# Rank 0 wrote 303 patches
# Rank 0 wrote 304 patches
# Rank 0 wrote 305 patches
# Rank 0 wrote 306 patches
# Rank 0 wrote 307 patches
# Rank 0 wrote 308 patches
# Rank 0 wrote 309 patches
# Rank 0 wrote 310 patches
# Rank 0 wrote 311 patches
# Rank 0 wrote 312 patches
# Rank 0 wrote 313 patches
# Rank 0 wrote 314 patches
# Rank 0 wrote 315 patches
# Rank 0 wrote 316 patches
# Rank 0 wrote 317 patches
# Rank 0 wrote 318 patches
# Rank 0 wrote 319 patches
# Rank 0 wrote 320 patches
# Rank 0 wrote 321 patches
# Rank 0 wrote 322 patches
# Rank 0 wrote 323 patches
# Rank 0 wrote 324 patches
# Rank 0 wrote 325 patches
# Rank 0 wrote 326 patches
# Rank 0 wrote 327 patches
# Rank 0 wrote 328 patches
# Rank 0 wrote 329 patches
# Rank 0 wrote 330 patches
# Rank 0 wrote 331 patches
# Rank 0 wrote 332 patches
# Rank 0 wrote 333 patches
# Rank 0 wrote 334 patches
# Rank 0 wrote 335 patches
# Rank 0 wrote 336 patches
# Rank 0 wrote 337 patches
# Rank 0 wrote 338 patches
# Rank 0 wrote 339 patches
# Rank 0 wrote 340 patches
# Rank 0 wrote 341 patches
# Rank 0 wrote 342 patches
# Rank 0 wrote 343 patches
# Rank 0 wrote 344 patches
# Rank 0 wrote 345 patches
# Rank 0 wrote 346 patches
# Rank 0 wrote 347 patches
# Rank 0 wrote 348 patches
# Rank 0 wrote 349 patches
# Rank 0 wrote 350 patches
# Rank 0 wrote 351 patches
# Rank 0 wrote 352 patches
# Rank 0 wrote 353 patches
# Rank 0 wrote 354 patches
# Rank 0 wrote 355 patches
# Rank 0 wrote 356 patches
# Rank 0 wrote 357 patches
# Rank 0 wrote 358 patches
# Rank 0 wrote 359 patches
# Rank 0 wrote 360 patches
# Rank 0 wrote 361 patches
# Rank 0 wrote 362 patches
# Rank 0 wrote 363 patches
# Rank 0 wrote 364 patches
# Rank 0 wrote 365 patches
# Rank 0 wrote 366 patches
# Rank 0 wrote 367 patches
# Rank 0 wrote 368 patches
# Rank 0 wrote 369 patches
# Rank 0 wrote 370 patches
# Rank 0 wrote 371 patches
# Rank 0 wrote 372 patches
# Rank 0 wrote 373 patches
# Rank 0 wrote 374 patches
# Rank 0 wrote 375 patches
# Rank 0 wrote 376 patches
# Rank 0 wrote 377 patches
# Rank 0 wrote 378 patches
# Rank 0 wrote 379 patches
# Rank 0 wrote 380 patches
# Rank 0 wrote 381 patches
# Rank 0 wrote 382 patches
# Rank 0 wrote 383 patches
# Rank 0 wrote 384 patches
# Rank 0 wrote 385 patches
# Rank 0 wrote 386 patches
# Rank 0 wrote 387 patches
# Rank 0 wrote 388 patches
# Rank 0 wrote 389 patches
# Rank 0 wrote 390 patches
# Rank 0 wrote 391 patches
# Rank 0 wrote 392 patches
# Rank 0 wrote 393 patches
# Rank 0 wrote 394 patches
# Rank 0 wrote 395 patches
# Rank 0 wrote 396 patches
# Rank 0 wrote 397 patches
# Rank 0 wrote 398 patches
# Rank 0 wrote 399 patches
# Rank 0 wrote 400 patches
# Rank 0 wrote 401 patches
# Rank 0 wrote 402 patches
# Rank 0 wrote 403 patches
# Rank 0 wrote 404 patches
# Rank 0 wrote 405 patches
# Rank 0 wrote 406 patches
# Rank 0 wrote 407 patches
# Rank 0 wrote 408 patches
# Rank 0 wrote 409 patches
# Rank 0 wrote 410 patches
# Rank 0 wrote 411 patches
# Rank 0 wrote 412 patches
# Rank 0 wrote 413 patches
# Rank 0 wrote 414 patches
# Rank 0 wrote 415 patches
# Rank 0 wrote 416 patches
# Rank 0 wrote 417 patches
# Rank 0 wrote 418 patches
# Rank 0 wrote 419 patches
# Rank 0 wrote 420 patches
# Rank 0 wrote 421 patches
# Rank 0 wrote 422 patches
# Rank 0 wrote 423 patches
# Rank 0 wrote 424 patches
# Rank 0 wrote 425 patches
# Rank 0 wrote 426 patches
# Rank 0 wrote 427 patches
# Rank 0 wrote 428 patches
# Rank 0 wrote 429 patches
# Rank 0 wrote 430 patches
# Rank 0 wrote 431 patches
# Rank 0 wrote 432 patches
# Rank 0 wrote 433 patches
# Rank 0 wrote 434 patches
# Rank 0 wrote 435 patches
# Rank 0 wrote 436 patches
# Rank 0 wrote 437 patches
# Rank 0 wrote 438 patches
# Rank 0 wrote 439 patches
# Rank 0 wrote 440 patches
# Rank 0 wrote 441 patches
# Rank 0 wrote 442 patches
# Rank 0 wrote 443 patches
# Rank 0 wrote 444 patches
# Rank 0 wrote 445 patches
# Rank 0 wrote 446 patches
# Rank 0 wrote 447 patches
# Rank 0 wrote 448 patches
# Rank 0 wrote 449 patches
# Rank 0 wrote 450 patches
# Rank 0 wrote 451 patches
# Rank 0 wrote 452 patches
# Rank 0 wrote 453 patches
# Rank 0 wrote 454 patches
# Rank 0 wrote 455 patches
# Rank 0 wrote 456 patches
# Rank 0 wrote 457 patches
# Rank 0 wrote 458 patches
# Rank 0 wrote 459 patches
# Rank 0 wrote 460 patches
# Rank 0 wrote 461 patches
# Rank 0 wrote 462 patches
# Rank 0 wrote 463 patches
# Rank 0 wrote 464 patches
# Rank 0 wrote 465 patches
# Rank 0 wrote 466 patches
# Rank 0 wrote 467 patches
# Rank 0 wrote 468 patches
# Rank 0 wrote 469 patches
# Rank 0 wrote 470 patches
# Rank 0 wrote 471 patches
# Rank 0 wrote 472 patches
# Rank 0 wrote 473 patches
# Rank 0 wrote 474 patches
# Rank 0 wrote 475 patches
# Rank 0 wrote 476 patches
# Rank 0 wrote 477 patches
# Rank 0 wrote 478 patches
# Rank 0 wrote 479 patches
# Rank 0 wrote 480 patches
# Rank 0 wrote 481 patches
# Rank 0 wrote 482 patches
# Rank 0 wrote 483 patches
# Rank 0 wrote 484 patches
# Rank 0 wrote 485 patches
# Rank 0 wrote 486 patches
# Rank 0 wrote 487 patches
# Rank 0 wrote 488 patches
# Rank 0 wrote 489 patches
# Rank 0 wrote 490 patches
# Rank 0 wrote 491 patches
# Rank 0 wrote 492 patches
# Rank 0 wrote 493 patches
# Rank 0 wrote 494 patches
# Rank 0 wrote 495 patches
# Rank 0 wrote 496 patches
# Rank 0 wrote 497 patches
# Rank 0 wrote 498 patches
# Rank 0 wrote 499 patches
# Rank 0 wrote 500 patches
# Writing to sample_0-4.tfrecord
# Rank 0 wrote 501 patches
# Rank 0 wrote 502 patches
# Rank 0 wrote 503 patches
# Rank 0 wrote 504 patches
# Rank 0 wrote 505 patches
# Rank 0 wrote 506 patches
# Rank 0 wrote 507 patches
# Rank 0 wrote 508 patches
# Rank 0 wrote 509 patches
# Rank 0 wrote 510 patches
# Rank 0 wrote 511 patches
# Rank 0 wrote 512 patches
# Rank 0 wrote 513 patches
# Rank 0 wrote 514 patches
# Rank 0 wrote 515 patches
# Rank 0 wrote 516 patches
# Rank 0 wrote 517 patches
# Rank 0 wrote 518 patches
# Rank 0 wrote 519 patches
# Rank 0 wrote 520 patches
# Rank 0 wrote 521 patches
# Rank 0 wrote 522 patches
# Rank 0 wrote 523 patches
# Rank 0 wrote 524 patches
# Rank 0 wrote 525 patches
# Rank 0 wrote 526 patches
# Rank 0 wrote 527 patches
# Rank 0 wrote 528 patches
# Rank 0 wrote 529 patches
# Rank 0 wrote 530 patches
# Rank 0 wrote 531 patches
# Rank 0 wrote 532 patches
# Rank 0 wrote 533 patches
# Rank 0 wrote 534 patches
# Rank 0 wrote 535 patches
# Rank 0 wrote 536 patches
# Rank 0 wrote 537 patches
# Rank 0 wrote 538 patches
# Rank 0 wrote 539 patches
# Rank 0 wrote 540 patches
# Rank 0 wrote 541 patches
# Rank 0 wrote 542 patches
# Rank 0 wrote 543 patches
# Rank 0 wrote 544 patches
# Rank 0 wrote 545 patches
# Rank 0 wrote 546 patches
# Rank 0 wrote 547 patches
# Rank 0 wrote 548 patches
# Rank 0 wrote 549 patches
# Rank 0 wrote 550 patches
# Rank 0 wrote 551 patches
# Rank 0 wrote 552 patches
# Rank 0 wrote 553 patches
# Rank 0 wrote 554 patches
# Rank 0 wrote 555 patches
# Rank 0 wrote 556 patches
# Rank 0 wrote 557 patches
# Rank 0 wrote 558 patches
# Rank 0 wrote 559 patches
# Rank 0 wrote 560 patches
# Rank 0 wrote 561 patches
# Rank 0 wrote 562 patches
# Rank 0 wrote 563 patches
# Rank 0 wrote 564 patches
# Rank 0 wrote 565 patches
# Rank 0 wrote 566 patches
# Rank 0 wrote 567 patches
# Rank 0 wrote 568 patches
# Rank 0 wrote 569 patches
# Rank 0 wrote 570 patches
# Rank 0 wrote 571 patches
# Rank 0 wrote 572 patches
# Rank 0 wrote 573 patches
# Rank 0 wrote 574 patches
# Rank 0 wrote 575 patches
# Rank 0 wrote 576 patches
# Rank 0 wrote 577 patches
# Rank 0 wrote 578 patches
# Rank 0 wrote 579 patches
# Rank 0 wrote 580 patches
# Rank 0 wrote 581 patches
# Rank 0 wrote 582 patches
# Rank 0 wrote 583 patches
# Rank 0 wrote 584 patches
# Rank 0 wrote 585 patches
# Rank 0 wrote 586 patches
# Rank 0 wrote 587 patches
# Rank 0 wrote 588 patches
# Rank 0 wrote 589 patches
# Rank 0 wrote 590 patches
# Rank 0 wrote 591 patches
# Rank 0 wrote 592 patches
# Rank 0 wrote 593 patches
# Rank 0 wrote 594 patches
# Rank 0 wrote 595 patches
# Rank 0 wrote 596 patches
# Rank 0 wrote 597 patches
# Rank 0 wrote 598 patches
# Rank 0 wrote 599 patches
# Rank 0 wrote 600 patches
# Rank 0 wrote 601 patches
# Rank 0 wrote 602 patches
# Rank 0 wrote 603 patches
# Rank 0 wrote 604 patches
# Rank 0 wrote 605 patches
# Rank 0 wrote 606 patches
# Rank 0 wrote 607 patches
# Rank 0 wrote 608 patches
# Rank 0 wrote 609 patches
# Rank 0 wrote 610 patches
# Rank 0 wrote 611 patches
# Rank 0 wrote 612 patches
# Rank 0 wrote 613 patches
# Rank 0 wrote 614 patches
# Rank 0 wrote 615 patches
# Rank 0 wrote 616 patches
# Rank 0 wrote 617 patches
# Rank 0 wrote 618 patches
# Rank 0 wrote 619 patches
# Rank 0 wrote 620 patches
# Rank 0 wrote 621 patches
# Rank 0 wrote 622 patches
# Rank 0 wrote 623 patches
# Rank 0 wrote 624 patches
# Rank 0 wrote 625 patches
# Rank 0 wrote 626 patches
# Rank 0 wrote 627 patches
# Rank 0 wrote 628 patches
# Rank 0 wrote 629 patches
# Rank 0 wrote 630 patches
# Rank 0 wrote 631 patches
# Rank 0 wrote 632 patches
# Rank 0 wrote 633 patches
# Rank 0 wrote 634 patches
# Rank 0 wrote 635 patches
# Rank 0 wrote 636 patches
# Rank 0 wrote 637 patches
# Rank 0 wrote 638 patches
# Rank 0 wrote 639 patches
# Rank 0 wrote 640 patches
# Rank 0 wrote 641 patches
# Rank 0 wrote 642 patches
# Rank 0 wrote 643 patches
# Rank 0 wrote 644 patches
# Rank 0 wrote 645 patches
# Rank 0 wrote 646 patches
# Rank 0 wrote 647 patches
# Rank 0 wrote 648 patches
# Rank 0 wrote 649 patches
# Rank 0 wrote 650 patches
# Rank 0 wrote 651 patches
# Rank 0 wrote 652 patches
# Rank 0 wrote 653 patches
# Rank 0 wrote 654 patches
# Rank 0 wrote 655 patches
# Rank 0 wrote 656 patches
# Rank 0 wrote 657 patches
# Rank 0 wrote 658 patches
# Rank 0 wrote 659 patches
# Rank 0 wrote 660 patches
# Rank 0 wrote 661 patches
# Rank 0 wrote 662 patches
# Rank 0 wrote 663 patches
# Rank 0 wrote 664 patches
# Rank 0 wrote 665 patches
# Rank 0 wrote 666 patches
# Rank 0 wrote 667 patches
# Rank 0 wrote 668 patches
# Rank 0 wrote 669 patches
# Rank 0 wrote 670 patches
# Rank 0 wrote 671 patches
# Rank 0 wrote 672 patches
# Rank 0 wrote 673 patches
# Rank 0 wrote 674 patches
# Rank 0 wrote 675 patches
# Rank 0 wrote 676 patches
# Rank 0 wrote 677 patches
# Rank 0 wrote 678 patches
# Rank 0 wrote 679 patches
# Rank 0 wrote 680 patches
# Rank 0 wrote 681 patches
# Rank 0 wrote 682 patches
# Rank 0 wrote 683 patches
# Rank 0 wrote 684 patches
# Rank 0 wrote 685 patches
